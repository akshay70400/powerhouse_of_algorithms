# %% [markdown]
# ![log2.1.PNG](attachment:log2.1.PNG)

# %% [markdown]
# ![log2.2.PNG](attachment:log2.2.PNG)

# %% [markdown]
# ![log2.3.PNG](attachment:log2.3.PNG)

# %% [markdown]
# ![log2.4.PNG](attachment:log2.4.PNG)
